# %%
import numpy as np

# %%
l = [1,2,3,4,5]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
l + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-61420124d028> in <cell line: 1>()
# ----> 1 l + 5
#
# TypeError: can only concatenate list (not "int") to list

# %%
narray = np.array([1,2,3,4,5])
print(narray)
# Out:
# [1 2 3 4 5]

# %%
print(type(l))
print(type(narray))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
narray + 5
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
narray * 5
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
narray.size
# Out:
# 5

# %%
arr1 = np.arange(10)

# %%
print(len(narray))
# Out:
# 5

# %%
arr2 = np.arange(20,38,2)

# %%
arr2.mean()
# Out:
# 28.0

# %%
arr2.max()
# Out:
# 36

# %%
arr2.min()
# Out:
# 20

# %%
arr2>25
# Out:
# array([False, False, False,  True,  True,  True,  True,  True,  True])

# %%
arr2[5]
# Out:
# 30

# %%
arr2[-1]
# Out:
# 36

# %%
arr2[arr2>25]
# Out:
# array([26, 28, 30, 32, 34, 36])

# %%
# !gdown 1PQhT_-kTg1JhTKFq0U-5MzQ4gARu-V3a
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PQhT_-kTg1JhTKFq0U-5MzQ4gARu-V3a
# To: /content/survey_large.txt
# 100% 21.8M/21.8M [00:00<00:00, 172MB/s]

# %%
scores = np.loadtxt('survey_large.txt', dtype='int')
scores
# Out:
# array([ 7, 10,  5, ...,  9,  5,  9])

# %%
scores.size
# Out:
# 10000000

# %%
scores.min()
# Out:
# 1

# %%
scores.max()
# Out:
# 10

# %%
scores.mean()
# Out:
# 7.250214

# %%
#detractors
det = scores[scores <= 6]
det
# Out:
# array([5, 4, 4, ..., 5, 4, 5])

# %%
#promotors
prom = scores[scores > 8]
prom
# Out:
# array([10,  9,  9, ..., 10,  9,  9])

# %%
nps = 100*(prom.size - det.size)/scores.size

# %%
nps
# Out:
# 23.73608

# %%
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O data.csv
# Out:
# --2023-07-27 16:34:31--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 108.177.111.100, 108.177.111.139, 108.177.111.113, ...
# Connecting to drive.google.com (drive.google.com)|108.177.111.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9pjb37jmlemtf5j2hemcbh8k8f3b3m8p/1690475625000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=e832e63f-b6bb-4c0d-90e4-a754b6eac541 [following]
# ...
# --2023-07-27 16:34:31--  https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/9pjb37jmlemtf5j2hemcbh8k8f3b3m8p/1690475625000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=e832e63f-b6bb-4c0d-90e4-a754b6eac541
# ...

# %%
df = pd.read_csv('data.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.size
# Out:
# 10224

# %%
df.shape
# Out:
# (1704, 6)

# %%
1704*6
#no. of rows X no. columns
# Out:
# 10224

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df['year']
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df['year']==2007
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703     True
# Name: year, Length: 1704, dtype: bool

# %%
df_2007 = df[df['year']==2007]

# %%
df_2007.head(20)
# Out:
#                     country  year  population continent  life_exp  \
# 11              Afghanistan  2007    31889923      Asia    43.828
# 23                  Albania  2007     3600523    Europe    76.423
# 35                  Algeria  2007    33333216    Africa    72.301
# 47                   Angola  2007    12420476    Africa    42.731
# 59                Argentina  2007    40301927  Americas    75.320
# 71                Australia  2007    20434176   Oceania    81.235
# 83                  Austria  2007     8199783    Europe    79.829
# 95                  Bahrain  2007      708573      Asia    75.635
# 107              Bangladesh  2007   150448339      Asia    64.062
# 119                 Belgium  2007    10392226    Europe    79.441
# 131                   Benin  2007     8078314    Africa    56.728
# 143                 Bolivia  2007     9119152  Americas    65.554
# 155  Bosnia and Herzegovina  2007     4552198    Europe    74.852
# ...

# %%
df_2007.min()
# Out:
# country       Afghanistan
# year                 2007
# population         199579
# continent          Africa
# life_exp           39.613
# gdp_cap        277.551859
# dtype: object

# %%
le_min = df_2007['life_exp'].min()

# %%
df_2007['life_exp'] == le_min
# Out:
# 11      False
# 23      False
# 35      False
# 47      False
# 59      False
#         ...
# 1655    False
# 1667    False
# 1679    False
# 1691    False
# 1703    False
# Name: life_exp, Length: 142, dtype: bool

# %%
df_2007[df_2007['life_exp'] == le_min]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 1463  Swaziland  2007     1133066    Africa    39.613  4513.480643

# %%
le_gdp = df_2007['gdp_cap'].max()

# %%
df_2007[df_2007['gdp_cap'] == le_gdp]
# Out:
#      country  year  population continent  life_exp      gdp_cap
# 1151  Norway  2007     4627926    Europe    80.196  49357.19017

# %%
df['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df_2007['continent'].value_counts()
# Out:
# Africa      52
# Asia        33
# Europe      30
# Americas    25
# Oceania      2
# Name: continent, dtype: int64

# %%
df['country'] == 'India'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
df_ind = df[df['country'] == 'India']
df_ind.head()
# Out:
#     country  year  population continent  life_exp     gdp_cap
# 696   India  1952   372000000      Asia    37.373  546.565749
# 697   India  1957   409000000      Asia    40.249  590.061996
# 698   India  1962   454000000      Asia    43.605  658.347151
# 699   India  1967   506000000      Asia    47.193  700.770611
# 700   India  1972   567000000      Asia    50.651  724.032527

# %%
#df_ind[['year','gdp_cap']]

col_list = ['year','gdp_cap']
df_ind[col_list]
# Out:
#      year      gdp_cap
# 696  1952   546.565749
# 697  1957   590.061996
# 698  1962   658.347151
# 699  1967   700.770611
# 700  1972   724.032527
# 701  1977   813.337323
# 702  1982   855.723538
# 703  1987   976.512676
# 704  1992  1164.406809
# 705  1997  1458.817442
# 706  2002  1746.769454
# 707  2007  2452.210407

# %%
df_ind.plot('year','gdp_cap')
# Out:
# <Axes: xlabel='year'>

# %%
df_ind.plot('year','life_exp')
# Out:
# <Axes: xlabel='year'>
